# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

import torch
import torch.nn as nn

import numpy as np
import torch.optim as optim
import torch.utils.data as data

# %%
covid_hospitalization_data = pd.read_csv("/Users/alex/Documents/Covid_Data/COVID-19_Reported_Patient_Impact_and_Hospital_Capacity_by_State_Timeseries__RAW_.csv")
covid_hospitalization_data["date"] = pd.to_datetime(covid_hospitalization_data["date"])
MA_data = covid_hospitalization_data[covid_hospitalization_data['state']=='MA'].sort_values('date')
MA_data.head()
# Out:
#       state       date  critical_staffing_shortage_today_yes  \
# 15475    MA 2020-03-27                                     0
# 17144    MA 2020-03-28                                     0
# 15869    MA 2020-03-29                                     0
# 20763    MA 2020-03-30                                     0
# 16094    MA 2020-03-31                                     0
#
#        critical_staffing_shortage_today_no  \
# 15475                                    0
# 17144                                    0
# 15869                                    0
# 20763                                    0
# 16094                                    0
#
#        critical_staffing_shortage_today_not_reported  \
# 15475                                              1
# 17144                                              1
# 15869                                              2
# 20763                                              6
# 16094                                             11
#
#        critical_staffing_shortage_anticipated_within_week_yes  \
# 15475                                                  0
# 17144                                                  0
# 15869                                                  0
# 20763                                                  0
# 16094                                                  0
#
#        critical_staffing_shortage_anticipated_within_week_no  \
# 15475                                                  0
# 17144                                                  0
# 15869                                                  0
# 20763                                                  0
# 16094                                                  0
#
#        critical_staffing_shortage_anticipated_within_week_not_reported  \
# 15475                                                  1
# 17144                                                  1
# 15869                                                  2
# 20763                                                  6
# 16094                                                 11
#
#        hospital_onset_covid  hospital_onset_covid_coverage  ...  \
# 15475                   0.0                              1  ...
# 17144                   0.0                              1  ...
# 15869                   0.0                              2  ...
# 20763                   0.0                              5  ...
# 16094                   0.0                              9  ...
#
#        previous_day_admission_pediatric_covid_confirmed_5_11_coverage  \
# 15475                                                  0
# 17144                                                  0
# 15869                                                  0
# 20763                                                  0
# 16094                                                  0
#
#        previous_day_admission_pediatric_covid_confirmed_unknown  \
# 15475                                                NaN
# 17144                                                NaN
# 15869                                                NaN
# 20763                                                NaN
# 16094                                                NaN
#
#        previous_day_admission_pediatric_covid_confirmed_unknown_coverage  \
# 15475                                                  0
# 17144                                                  0
# 15869                                                  0
# 20763                                                  0
# 16094                                                  0
#
#        staffed_icu_pediatric_patients_confirmed_covid  \
# 15475                                             NaN
# 17144                                             NaN
# 15869                                             NaN
# 20763                                             NaN
# 16094                                             NaN
#
#        staffed_icu_pediatric_patients_confirmed_covid_coverage  \
# 15475                                                  0
# 17144                                                  0
# 15869                                                  0
# 20763                                                  0
# 16094                                                  0
#
#        staffed_pediatric_icu_bed_occupancy  \
# 15475                                  NaN
# 17144                                  NaN
# 15869                                  NaN
# 20763                                  NaN
# 16094                                  NaN
#
#        staffed_pediatric_icu_bed_occupancy_coverage  \
# 15475                                             0
# 17144                                             0
# 15869                                             0
# 20763                                             0
# 16094                                             0
#
#        total_staffed_pediatric_icu_beds  \
# 15475                               NaN
# 17144                               NaN
# 15869                               NaN
# 20763                               NaN
# 16094                               NaN
#
#        total_staffed_pediatric_icu_beds_coverage  \
# 15475                                          0
# 17144                                          0
# 15869                                          0
# 20763                                          0
# 16094                                          0
#
#        Demo | State Geographic Boundaries
# 15475                                 NaN
# 17144                                 NaN
# 15869                                 NaN
# 20763                                 NaN
# 16094                                 NaN
#
# [5 rows x 136 columns]

# %%
target_variable = ['total_adult_patients_hospitalized_confirmed_covid']

pa_MA_data = MA_data[[target_variable[0]]].dropna().values.astype('float32')
len(pa_MA_data)
# Out:
# 1056

# %%
train_size = int(len(pa_MA_data) * 0.67)
test_size = len(pa_MA_data) - train_size
train, test = pa_MA_data[:train_size], pa_MA_data[train_size:]

# %%
def create_dataset(dataset, lookback):
    """Transform a time series into a prediction dataset
    
    Args:
        dataset: A numpy array of time series, first dimension is the time steps
        lookback: Size of window for prediction
    """
    X, y = [], []
    for i in range(len(dataset)-lookback):
        feature = dataset[i:i+lookback]
        target = dataset[i+1:i+lookback+1]
        X.append(feature)
        y.append(target)
    return torch.tensor(X), torch.tensor(y)

# %%
lookback = 7
X_train, y_train = create_dataset(train, lookback=lookback)
X_test, y_test = create_dataset(test, lookback=lookback)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# torch.Size([700, 7, 1]) torch.Size([700, 7, 1])
# torch.Size([342, 7, 1]) torch.Size([342, 7, 1])

# %%
import torch.nn as nn
 
class AirModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.lstm = nn.LSTM(input_size=1, hidden_size=50, num_layers=1, batch_first=True)
        self.linear = nn.Linear(50, 1)
    def forward(self, x):
        x, _ = self.lstm(x)
        x = self.linear(x)
        return x

# %%
class MAPELoss(nn.Module):
    def __init__(self):
        super(MAPELoss, self).__init__()

    def forward(self, y, y_hat):
        mape = torch.abs(y - y_hat) / torch.abs(y)
        mape = torch.mean(mape)
        return mape

# %%
model = AirModel()
optimizer = optim.Adam(model.parameters())
loss_fn = MAPELoss()
loader = data.DataLoader(data.TensorDataset(X_train, y_train), shuffle=True, batch_size=8)
 
n_epochs = 2000
for epoch in range(n_epochs):
    model.train()
    for X_batch, y_batch in loader:
        y_pred = model(X_batch)
        loss = loss_fn(y_pred, y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    # Validation
    if epoch % 100 != 0:
        continue
    model.eval()
    with torch.no_grad():
        y_pred = model(X_train)
        train_rmse = loss_fn(y_pred, y_train)
        y_pred = model(X_test)
        test_rmse = loss_fn(y_pred, y_test)
    print("Epoch %d: train MAPE %.4f, test MAPE %.4f" % (epoch, train_rmse, test_rmse))
# Out:
# Epoch 0: train MAPE 275.0057, test MAPE 237.0717
# Epoch 100: train MAPE 7.1916, test MAPE 6.0643
# Epoch 200: train MAPE 1.9578, test MAPE 1.5007
# Epoch 300: train MAPE 0.6336, test MAPE 0.3150
# Epoch 400: train MAPE 0.3033, test MAPE 0.0817
# Epoch 500: train MAPE 0.1928, test MAPE 0.0504
# Epoch 600: train MAPE 0.1377, test MAPE 0.0379
# Epoch 700: train MAPE 0.1115, test MAPE 0.0359
# Epoch 800: train MAPE 0.0935, test MAPE 0.0409
# Epoch 900: train MAPE 0.0820, test MAPE 0.0356
# Epoch 1000: train MAPE 0.0741, test MAPE 0.0387
# Epoch 1100: train MAPE 0.0735, test MAPE 0.0363
# Epoch 1200: train MAPE 0.0679, test MAPE 0.0371
# Epoch 1300: train MAPE 0.0658, test MAPE 0.0369
# Epoch 1400: train MAPE 0.0628, test MAPE 0.0373
# Epoch 1500: train MAPE 0.0579, test MAPE 0.0357
# Epoch 1600: train MAPE 0.0646, test MAPE 0.0391
# Epoch 1700: train MAPE 0.0590, test MAPE 0.0349
# Epoch 1800: train MAPE 0.0590, test MAPE 0.0382
# Epoch 1900: train MAPE 0.0569, test MAPE 0.0354

# %%
with torch.no_grad():
    # shift train predictions for plotting
    train_plot = np.ones_like(pa_MA_data) * np.nan
    y_pred = model(X_train)
    y_pred = y_pred[:, -1, :]
    train_plot[lookback:train_size] = model(X_train)[:, -1, :]
    # shift test predictions for plotting
    test_plot = np.ones_like(pa_MA_data) * np.nan
    test_plot[train_size+lookback:len(pa_MA_data)] = model(X_test)[:, -1, :]
# plot
plt.plot(pa_MA_data, c='b')
plt.plot(train_plot, c='r')
plt.plot(test_plot, c='g')
plt.show()

# %%
plt.plot(pa_MA_data, c='b')
plt.plot(train_plot, c='r')
plt.plot(test_plot, c='g')
plt.xlim([len(pa_MA_data) - test_size,len(pa_MA_data)])
plt.ylim([0,1500])
plt.show()

# %%
plt.plot(pa_MA_data, c='b')
plt.plot(train_plot, c='r')
plt.plot(test_plot, c='g')
plt.xlim([10,30])
plt.ylim([0,1500])
plt.show()
